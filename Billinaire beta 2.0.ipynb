# %%
pip install kivy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 1.4 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyChatGPT
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SpeechRecognition
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import objc

# %%
pip install Foundation
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 660.9 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 6.5 MB/s eta 0:00:0000:0100:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for Foundation: filename=foundation-0.1.0a0.dev1-py3-none-any.whl size=73539 sha256=7f798a630491a9c1e87d1189f6482d4df713a6b764ed1a15bb5fd4efcdaf3457
#   Stored in directory: /Users/mahinrahman/Library/Caches/pip/wheels/e5/23/fe/db20ac0f26c74445459281709ae08c2da45026a521a2616b91
# Successfully built Foundation
# ...
#   Attempting uninstall: Django
#     Found existing installation: Django 3.2.7
#     Uninstalling Django-3.2.7:
#       Successfully uninstalled Django-3.2.7
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U pyobjc
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 kB 1.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 960.0 kB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.4/404.4 kB 5.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 129.4 kB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: pyobjc-core
#     Found existing installation: pyobjc-core 7.3
#     Uninstalling pyobjc-core-7.3:
#       Successfully uninstalled pyobjc-core-7.3
#   Attempting uninstall: pyobjc-framework-libdispatch
#     Found existing installation: pyobjc-framework-libdispatch 7.3
#     Uninstalling pyobjc-framework-libdispatch-7.3:
#       Successfully uninstalled pyobjc-framework-libdispatch-7.3
#   Attempting uninstall: pyobjc-framework-Cocoa
#     Found existing installation: pyobjc-framework-Cocoa 7.3
#     Uninstalling pyobjc-framework-Cocoa-7.3:
# ...

# %%
pip install keyboard
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyQt5
import sys
from PyQt5.QtCore import pyqtSlot, QRect
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QVBoxLayout, QLabel, QTableWidget, QTableWidgetItem, QHeaderView
from PyQt5.QtGui import QPixmap
import xlsxwriter as xl
from pyChatGPT import ChatGPT
import speech_recognition as sr
import keyboard
import pyttsx3


session_token = "eyJhbGciOiJkaXIiLCJlbmMiOiJBMjU2R0NNIn0..ZYslw79CSxE3z4sK.c5HQh3kpmPDy56yz1MjCKKyE6BWtV0tIehtOWpVjDnlf2PQmz5QIwU-zhTloBD1OY-e6aJRcXLYkFFmkRIR2WRFJiki-7xXD4Q0c8Y-WDvU8LIKpYFalopMkHQ2dN1Uyy7i9-4ji2U59ElQqzUOoK-SAIHKLXucOD5hPx92MF5Nx1CIZh2RcmEdV7LYBaEDaQc1qjUGgL7Fpfwovsve_Yyz2bbtiPSjGaQHg48Wh8gGDFFDLlEUugnYjChlW_CKB9j-My2uQf4Wz2SGcquy2CF71n7hk9Kzot9Y5-GHKqkWU0PCxd3Rx4eBDznbjnKKN8pqRqySC4mcrM2p1sIEqQyPqt3jv46JOLlUYxBU89M0pGNwVs51P9PJFxIt8_CfvRA_rO_sB5vS2c4A9nVvHD9nsDh--4JRsi24JZ-tOOijFn8Ppxdpl656CdNSJDgDTAUKcHAm_FaYniOZC5lAZ13ekbqilbv1zyTs2tRz4s1o3cENDXvsoflBrdF3e5DNa79ebJRvPdRzkjHXSeJ0UPmQW54GGK7RFYjlzis72uIUcUGqdIGbg7KevKuoDPNVs0m5vkq153H00VDEaprDxR50QGzdXJSbNIteh6hXZ1ZpN8IMPnNqRpKoIphp8m3-CAnCpt0nFuKpYFtu4YMoBNjmn_8zidnJW1pXKt5Pg3aK_0e8hrxMPLbcvMjyz5nTr0Dw12
l3awbxx1KJtkrABMBxMgMA1gNtE_EBbhQTPEx7GiP3kiS_v9_9e3O1e5D1wTDqbMAYx3F0BfZ6_cpWb72l-EfKtIPOsGBjIYIBeitNf07KVS-hzxpJKAEiTOAyOn6h5J7-4aw3ZaITgP9sgUEwWEdNEdGNf_oEuL9HnoDPkSPZuxq3myA9zjWrsF0rTIuCVahtDknII9ysPLztume96rwqcCitK5KII8q4d5_d22nTUM98zZBWLzW6bW2SLD0LqktF9Gy9gIauH3CKE_pkqwPwEkUPd7YRwjAReV3kq0b9ATnzLC-HWSRnl0qEqx1GN8K76zl6vxZaSKMTmCHSuvs2nheCwtHY6-SMDlmI6Ku0a4wqsRWznBb0zq_ZGugAXLVFFpQDw.d9IP9nIo3xQ6wM65BLmL7Q"
api = ChatGPT(session_token)

r = sr.Recognizer()

engine = pyttsx3.init()



def give_me_text():

    with sr.Microphone() as source:
        print("Talk")
        audio_text = r.listen(source) 
        print("Time over, thanks")
        
    try:

        var  =  r.recognize_google(audio_text)
        
    except:
        var = "Sorry, I did not get that"
    return var


def mainreply():
    
    v = give_me_text()

    #print(var)

    resp = api.send_message(v)

    res = (resp["message"])
    speak_now(res)
    #print("result = ",res)
    # engine.say(res)
    # engine.runAndWait()

def speak_now(res):
    engine.say(res)
    engine.runAndWait()






class App(QWidget):
    def __init__(self):
        super().__init__()
       
        #Initializing the parameters
        self.title = "Billionaire"
        self.left = 500
        self.top = 200
        self.width = 1080
        self.height = 720
        self.initUI()
       
       
    def initUI(self):
        self.setWindowTitle(self.title)
        self.setGeometry(self.left,self.top,self.width,self.height)
       
       
        vbox = QVBoxLayout()
       
        #Setting Background Image
        labelImage = QLabel(self)
        pixmap = QPixmap("chatbg.jpg")
        labelImage.setPixmap(pixmap)
       
        vbox.addWidget(labelImage)
        self.setLayout(vbox)
       
       
       
       
       
        #Button2 declaration and design
        #self.button2 = QPushButton("Stop Attendence",self)
        #self.button2.setGeometry(QRect(300,360,150,50))
        #self.button2.setToolTip("Will Create an Excel File")
               
        #self.button2.setStyleSheet("QPushButton"
        #                     "{"
        #                     "background-color : lightblue;"
        #                     "}"
        #                     "QPushButton::hover"
        #                     "{"
        #                     "background-color : red;"
        #                    "}"
        #                     )
        #self.button2.clicked.connect(self.off_cam)
       

       
        #Button1 declaration and design
        self.button = QPushButton("Start Talking",self)
        self.button.setToolTip("Start taking response")
        self.button.setGeometry(QRect(540,360,150,50))
        self.button.setStyleSheet("QPushButton"
                             "{"
                             "background-color : lightblue;"
                             "}"
                             "QPushButton::hover"
                             "{"
                             "background-color : green;"
                             "}")
        self.button.clicked.connect(self.talk)

        self.show()


    @pyqtSlot()

    def talk(self):
        #Calling the face detection class
        t = mainreply()

        
        
        
        
        
        
        
        
        
        
        

if __name__ == "__main__":
    app = QApplication(sys.argv)
    ex = App()
    sys.exit(app.exec_())
